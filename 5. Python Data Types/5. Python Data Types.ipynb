# %% [markdown]
# ## **Python Data Types**
#
# ## Built-in Data Types
#
# In programming, data type is an import concept.
#
# Variables can store data of diiferent types, and different types can do different things.
#
# Python has the following data types built-in by default, in these categories:
#
#  Text Type:         Str
#
#  Numeric Types:     int, float, complex
#
#  Sequence Types:    list, tuple, range
#
#  Mapping Type:      dict
#
#  Set Types:         set, forzenset
#
#  Boolean Type:      bool
#
#  Binary Types:      bytes, bytearray, memoryview
#
#  None Type:         NoneType

# %% [markdown]
# ## Getting the Data Type
#
# You can get the data type of any object by using the type() function:
#
# ## Example
#
# print the data type of the variable x:

# %%
x = 5
print(type(x))
# Out:
# <class 'int'>

# %% [markdown]
# ## Setting the Data Type
#
# In Python, the data type is set when you assign a value to a variable:
#
# ![image.png](attachment:2302249c-e6bd-4832-b035-ff0a1bfeb04d.png)
#
# ![image.png](attachment:8d0ad03f-c939-4428-b64e-745df01a746a.png)

# %% [markdown]
# ## Eaxmple

# %%
x = "Hello Worls"
print(type(x))
# Out:
# <class 'str'>

# %%
x = 20
print(type(x))
# Out:
# <class 'int'>

# %%
x = 20.5
print(type(x))
# Out:
# <class 'float'>

# %%
x = 1j
print(type(x))
# Out:
# <class 'complex'>

# %%
x = ["apple", "banana", "cherry"]
print(type(x))
# Out:
# <class 'list'>

# %%
x = ("apple", "banana", "cheery")
print(type(x))
# Out:
# <class 'tuple'>

# %%
x = range(6)
print(type(x))
# Out:
# <class 'range'>

# %%
x = {"name" : "john", "age" : 36}
print(type(x))
# Out:
# <class 'dict'>

# %%
x = {"apple", "banana", "cherry"}
print(type(x))
# Out:
# <class 'set'>

# %%
x = frozenset({"apple", "banana"})
print(type(x))
# Out:
# <class 'frozenset'>

# %%
x = True
print(type(x))
# Out:
# <class 'bool'>

# %%
y = b"Hello"
print(type(x))
# Out:
# <class 'bool'>

# %%
x = bytearray(5)
print(type(x))
# Out:
# <class 'bytearray'>

# %%
x = memoryview(bytes(5))
print(type(x))
# Out:
# <class 'memoryview'>

# %%
x = None
print(type(x))
# Out:
# <class 'NoneType'>

# %% [markdown]
# ## Setting the Specific Data Type
#
# if you want to specify the data type, you can use the following constructor functions:
#
# ![image.png](attachment:19f4429b-70df-4235-92e9-13790acb83f1.png)
#
# ![image.png](attachment:800909b7-fd29-4813-b027-19a92498f5c9.png)

# %% [markdown]
# ## Example Data Type

# %%
x = str("Hello World")
print(type(x))
x
# Out:
# <class 'str'>
# 'Hello World'

# %%
x = int(20)
print(type(x))
x
# Out:
# <class 'int'>
# 20

# %%
x = float(20.5)
print(type(x))
x
# Out:
# <class 'float'>
# 20.5

# %%
x = complex(1j)
print(type(x))
x
# Out:
# <class 'complex'>
# 1j

# %%
x = list(("apple", "banaan", "cherry"))
print(type(x))
x
# Out:
# <class 'list'>
# ['apple', 'banaan', 'cherry']

# %%
x = tuple(("apple", "banana", "cherry"))
print(type(x))
x
# Out:
# <class 'tuple'>
# ('apple', 'banana', 'cherry')

# %%
x = dict(name = "John", age = 36)
print(type(x))
x
# Out:
# <class 'dict'>
# {'name': 'John', 'age': 36}

# %%
x = set(("apple", "banana", "cherry"))
print(type(x))
x
# Out:
# <class 'set'>
# {'apple', 'banana', 'cherry'}

# %%
x = frozenset(("apple", "banana", "cherry"))
print(type(x))
x
# Out:
# <class 'frozenset'>
# frozenset({'apple', 'banana', 'cherry'})

# %%
x = bool(5)
print(type(x))
x
# Out:
# <class 'bool'>
# True

# %%
x = bytes(5)
print(type(x))
x
# Out:
# <class 'bytes'>
# b'\x00\x00\x00\x00\x00'

# %%
x = bytearray(5)
print(type(x))
x
# Out:
# <class 'bytearray'>
# bytearray(b'\x00\x00\x00\x00\x00')

# %%
x = memoryview(bytes(5))
print(type(x))
x
# Out:
# <class 'memoryview'>

# %% [markdown]
# # Exercise
#
# ![image.png](attachment:0637688b-9fda-4afb-8dfd-b1f694248911.png)
#
# ![image.png](attachment:80269a85-465b-465b-9f61-42591ad2f00a.png)
#
# ![image.png](attachment:0024e018-ea5b-444a-bc47-44237082f1c0.png)
#
# ![image.png](attachment:07ba3e8d-8ab7-4ea2-b8fd-ce777e8558e2.png)
#
# ![image.png](attachment:19bd96cb-6c57-4bc8-a78f-1f69540bd865.png)
#
# ![image.png](attachment:01f529c4-b59e-4655-8b76-cd688681d733.png)
#
# ![image.png](attachment:d62953bd-454c-4ec6-babb-8cf324636105.png)
#
# ![image.png](attachment:50316425-3067-4ab8-ab45-6d80fba59a23.png)
#
# ## Answers
#
# ![image.png](attachment:a589664d-53b9-4a66-b1bd-0c4f6f3230fb.png)
#
# ![image.png](attachment:eed4a189-9687-404e-b84c-0568fcf9797c.png)
#
# ![image.png](attachment:931a6337-f944-48e7-9519-e59d5785dc06.png)
#
# ![image.png](attachment:570d7e06-26a4-4320-b681-e07b96681e94.png)
#
# ![image.png](attachment:7b42e705-35f6-45e6-b52c-81c8003933f3.png)
