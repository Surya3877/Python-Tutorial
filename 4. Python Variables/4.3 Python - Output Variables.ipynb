# %% [markdown]
# # Python - Output Variables
#
# ## Output Variables
#
# The Python **print()** functions is often used to output variables.
#
# ## Example

# %%
x = "Python is awesome"
print(x)
# Out:
# Python is awesome

# %% [markdown]
# ## **Separated by a comma**
#
# In the **print()** function, you output multiple variables, separated by a comma:
#
# ## Example

# %%
x = "Python"
y = "is"
z = "awesome"
print(x, y, z)
# Out:
# Python is awesome

# %% [markdown]
# ## **+ Operator**
#
# You can also use the **+** operator to ouput multiple variables
#
# ## Example

# %%
x = "Python "
y = "is "
z = "awesome"
print(x + y + z)
# Out:
# Python is awesome

# %% [markdown]
# ![image.png](attachment:a6415aef-14e9-4adf-a0f7-dd51e680e4e3.png)

# %% [markdown]
# For numbers, the + character works as a mathematical operator:
#
# ## Example

# %%
x = 5
y = 10
print(x + y)
# Out:
# 15

# %% [markdown]
# In **print()** function, when you try to combine a string and a number with the + operator, Python will give you an error:
# ## Example

# %%
x = 5
y = "John"
print(x + y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 x = 5
#       2 y = "John"
# ----> 3 print(x + y)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# The best way to output multiple variables in the **print()** function is to separate them with commas, which even support different data types:
# ## Example

# %%
x = 5
y = "John"
print(x, y)
# Out:
# 5 John

# %% [markdown]
# # Exercise
#
# ![image.png](attachment:90d0a8d3-024d-4eb6-85a3-a99c63104141.png)
#
# ![image.png](attachment:a92266d0-2f62-4e5b-b27b-93e243d6b265.png)
#
# ![image.png](attachment:32a7a834-473d-4114-9679-b9416a987015.png)
#
# ## Answers
#
# ![image.png](attachment:7ea96140-339b-42a1-904e-a81eab1e073f.png)
#
# ![image.png](attachment:3cdfc5e6-619f-47a2-ac11-abb3b3d55213.png)
#
# ![image.png](attachment:0bdb0ef6-b27f-4cc1-a3dc-6e66ad41663f.png)
