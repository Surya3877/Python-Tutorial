# %% [markdown]
# # Python - Variable Names
#
# ## Variable Names
#
# A variable can have a short name (like x and y) or a more descriptive name (age, carname, total_volume).
#
# Rules for Python variables:
#
# - A variable name must start with a letter ot the underscore character
# - A variable name cannot start with a number
# - A variable name can only contain alpha-numeric characters and underscores (A-Z, 0-9, and_)
# - Variable names are case-sensitive (age, Age and AGE are three different variables)
# - A variable name cannot be any of the python keywords.
#
# ## Example
#
# Legal variable names:

# %%
myvar = "John"
my_var = "John"
_my_var = "John"
myVar = "John"
myvar2 = "John"

# %% [markdown]
# ![image.png](attachment:3a38b4d2-9712-4e7f-8595-d06a0f57328f.png)

# %% [markdown]
# ### Multi Words Variable Names
#
# Variable names with more than one word can be difficult to read.
#
# There are several techniques you can use to make them more readable:
#
# ## Camel Case
#
# Each word, except the first, start with a captical letter:
#
# ![image.png](attachment:94553c77-88b2-4216-b760-e1c1f3361f51.png)
#
# ## Pascal Case
#
# Each word starts with a capital letter:
#
# ![image.png](attachment:118e3279-b8d1-4b98-bc50-b31752e8a68a.png)
#
# ## Snake Case
#
# ![image.png](attachment:50600f99-c9c5-4754-9b2f-9615e0cf3ff2.png)

# %% [markdown]
# # Execrise
#
# ![image.png](attachment:7e46213e-1b1d-4b20-a4b1-263ac46febbe.png)
#
# ![image.png](attachment:dde2a026-b26f-490c-8cf0-23c0788b0842.png)
#
# ![image.png](attachment:93aa954d-fd0c-48a4-9d69-c733bee4388d.png)
#
# ## Answer
#
# ![image.png](attachment:9ee189f3-00ae-4a93-8a44-ab030b0fa9a6.png)
#
# ![image.png](attachment:8ff20b20-9fba-4b34-a2b8-e355dabfdde2.png)
#
# ![image.png](attachment:1fba7f14-32d6-4182-813d-36d944713edf.png)
