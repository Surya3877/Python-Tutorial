# %% [markdown]
# # Python Variables
#
# ## Variables
#
# Variables are containers for storing data values.
#
# ## Creating Variables
#
# Python has no command for declaring a variable.
#
# A variable is created the moment you first assign a value to it.
#
# ## Example

# %%
x = 5
y = "john"
print(x)
print(y)
# Out:
# 5
# john

# %% [markdown]
# Variables do not need to be declared with any particular type, and even change type after they have been set.
#
# ## Example

# %%
x = 4        # x is of type int
x = "Sally"  # x is now of type str
print(x)
# Out:
# Sally

# %% [markdown]
# ## Casting
#
# if you want to specify the data type of a variable, this can be done with casting.
#
# ## Example

# %%
x = str(3)     # x will be '3'
y = int(3)     # y will be 3
z = float(3)   # z will be 3.0

# %% [markdown]
# ## Get the Type
#
# You can get the data type of a variable with type() function.
#
# ## Example

# %%
x = 5
y = "John"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# ## Single or Double Quotes?
#
# String variables can be declared either by using single or double quotes:
#
# ## Example

# %%
x = "John"
# is the same as
x = 'John'

x
# Out:
# 'John'

# %% [markdown]
# ## Case-Sensitive
#
# Variable names are case-sensitive.
#
# ## Example
#
# This will create two variables:

# %%
a = 4
A = "Sally "
#A will not over overwrite a

# %% [markdown]
# # Exercise
#
# ![image.png](attachment:e914d294-ab39-425d-805d-3e11208893f2.png)
#
# ![image.png](attachment:0c996526-c0e5-4c41-b7f8-04ab761d2649.png)
#
# ![image.png](attachment:d6675a3c-4b7d-44d5-a9eb-a77a36fd1cbc.png)
#
# ![image.png](attachment:c53842ac-7bbd-4d4f-b0aa-58cfe88ba5ea.png)
#
# ## Answers
#
# ![image.png](attachment:fa86f9f2-2d6b-4ea4-b6c5-5ebc1c44e206.png)
#
# ![image.png](attachment:6571ce38-275e-4b74-aaaf-4687a8b83a6a.png)
#
# ![image.png](attachment:4b490089-8a44-4a7c-b7d0-2dd281e7dd23.png)
