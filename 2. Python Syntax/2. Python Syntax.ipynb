# %% [markdown]
# # **Python Syntax**

# %% [markdown]
# ## On this Page
#
# Execute Python
#
# Python Indentation
#
# Python Variables
#
# Python Comments
#
# Exercise

# %% [markdown]
# ## Execute Python Syntax
#
# As we learned in the previous page, Python syntax can be executed by writting directly in the command line:
#
# ![image.png](attachment:0eb8f7c8-73d7-4567-a039-a93b1014b471.png)
#
# Or by creating a python file on the server, using the .py file extension, and running it in the Command Line:
#
# ![image.png](attachment:f6a13deb-09c5-4dab-bf63-0bf90c0bc315.png)

# %% [markdown]
# ## Python Indentation
#
# Indentation refers to the spaces at the beginning of a code line.
#
# Where in other programming languages the indentation in code is for readability only, the indentation in Python is very important.
#
# Python uses indentation to indentation to indicate a block of code.
#
# ## Example

# %%
if 5 > 2:
    print("Five is greater than two!")
# Out:
# Five is greater than two!

# %% [markdown]
# Python will give you an error if you skip the identation:
#
# ![image.png](attachment:582e9617-de8d-4ccc-b546-8f52acd1e7ae.png)
#
# The number of spaces is up to you as a programmer, the most coomom use is four, but has to be at least one.
#
# ## Example

# %%
if 5 > 2:
    print("Five is greater than two!")
if 5 > 2:
        print("FIve is greater than two!")
# Out:
# Five is greater than two!
# FIve is greater than two!

# %% [markdown]
# You have to use the same number of spaces in the same block of code, otherwise Python will give you an error:
#
# ![image.png](attachment:94a21a67-7178-4aca-a2ab-7d0ad4f1dfe4.png)

# %% [markdown]
# ## Python Variables
#
# In Python, variables are created when you assign a value to it:
#
# ## Example
#
# Variables in Python:

# %%
x = 5
y = "Hello, World!"

# %%
x
# Out:
# 5

# %%
y
# Out:
# 'Hello, World!'

# %% [markdown]
# Python has no command for declaring a variable.
#
# You will learn more abount variable in the Python Variables chapter.

# %% [markdown]
# ## Comments
#
# Python has commenting capability for the purpose of in-code documentation.
#
# Comments start with a #, and Python will render the rest of the line as a comment:
#
# ## Example
#
# Comments in Python:

# %%
# This is a comment.
print("Hello, Worls!")
# Out:
# Hello, Worls!

# %% [markdown]
# # Exercise
#
# ![image.png](attachment:79719481-9bc6-4c54-8cf3-4369e48e5728.png)
#
# ![image.png](attachment:86a81be8-140a-47cb-848b-1b2311c78e58.png)
#
# ![image.png](attachment:611a509c-11cf-4edc-960e-f5f23f6a29b8.png)
#
# ## Answers
#
# ![image.png](attachment:ec46839d-999a-432d-9a43-63654eb6db7c.png)
#
# ![image.png](attachment:0f5d1607-e7eb-4536-b35b-779bfcf3ab48.png)
#
# ![image.png](attachment:5d7cb74f-d41b-49e9-83fc-716a484db875.png)
