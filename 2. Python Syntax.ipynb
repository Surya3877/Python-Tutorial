# %% [markdown]
# # **Python Syntax**

# %% [markdown]
# ## **Execute Python Syntax**
# - As we learned in the previous page, Python syntax can be exectued by writing directly in the Command Line.

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# Or by creating a Python file on the server, using the .py file extension, and running It in the Command Line:

# %% [markdown]
# C:\Users\Your Name>python myfile.py

# %% [markdown]
# # **Python Indentation**
# - Indentation refers to the spaces at the beginning of a code line.
# - Where in other programming languages the indentation in code is for for readability only, the indentation in Python is very important.
# - Python uses indentation to indicate a block of code.

# %% [markdown]
# ## **Example**

# %%
if 5>2:
    print("Five is greater than two!")
# Out:
# Five is greater than two!

# %% [markdown]
# ## **Python will give you an error if you skip the indentation:**
# **Example**
# Syntax Error:

# %%
if 5 > 2:
Print("Five is greater than two!")
# Out:
#   Cell In[5], line 2
#     Print("Five is greater than two!")
#     ^
# IndentationError: expected an indented block

# %% [markdown]
# **The number of spaces is upto you as a programmer, the most common use is four, but it has to be at least one.**

# %%
if 5 > 2:
    print("Five is greater than two!")
if 5 > 2:
        print("Five is greater than two!")
# Out:
# Five is greater than two!
# Five is greater than two!

# %% [markdown]
# **You have to use the same number of spaces in the same block of code, otherwise Python will give you an error:**

# %%
if 5 > 2:
    print("Five is greater than two!")
        print("Five is greater than two!")
# Out:
#   Cell In[8], line 3
#     print("Five is greater than two!")
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# # **Python variable**
#
# In Python, variable are created when you assign a value to it:
#
# **Example**
#
# Variable in Python:

# %%
x = 5
y = "Hello World!"

# %% [markdown]
# Python has no command for decting a variable.
#
# You will learn more about variables in the **Python Variable chapter.**

# %% [markdown]
# # **Comments**
#
# Python has commeting capability for the purpose of In-code documentation.
#
# Comments start with a #, and Python will rwnder the rest of the line as a comment:

# %%
# This is a comment
print("Hello, World!")
# Out:
# Hello, World!
